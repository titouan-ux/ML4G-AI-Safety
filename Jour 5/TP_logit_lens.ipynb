# %%
pip install transformers -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 67.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.8/294.8 kB 25.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 120.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 70.0 MB/s eta 0:00:00

# %%
from transformers import GPT2Tokenizer, GPT2Model
import torch
import pandas as pd
from google.colab import data_table
from tqdm.notebook import tqdm
data_table.enable_dataframe_formatter()

# %%
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2Model.from_pretrained('gpt2')
# Out:
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]

# %%
input_sentence = "Specifically, we train GPT-3, an autoregressive language model, with 175 billion parameters,"
input_embedding = tokenizer(input_sentence, return_tensors="pt").input_ids
embedding_matrix = model.wte.weight
print(f"emb shape {embedding_matrix.shape}")
# print(type(input_embedding), input_embedding)
model_output = model(input_embedding, output_hidden_states=True)
hidden_states = model_output.hidden_states
# Out:
# emb shape torch.Size([50257, 768])

# %%
# # help(tokenizer.decode)
# print(*[a.shape for a in hidden_states]
# # help(model)

# %%
def desembed_state(state):
  return torch.einsum('We,we->wW', [embedding_matrix, state])

def detokenize(output):
  output = desembed_state(output)
  output = torch.argmax(output, dim = 1)
  out = []
  for e in output:
    out.append(tokenizer.decode(e))
  return out

# %%
def get_1best(hidden_states):
  return [detokenize(s[0]) for s in hidden_states]

# %%
best1 = get_1best(hidden_states)
# print(detokenize(model_output.last_hidden_state))
best1[0] = best1[0][1::] + ["NEXT_TOKEN"]

df = pd.DataFrame(best1[1::][::-1], columns=best1[0])
df.index.name = "Layer"
df.index = df.index[::-1]
df
# Out:
# Warning: Total number of columns (21) exceeds max_columns (20). Falling back to pandas display.
#           ,    we  train       G  PT      -      3    ,    an      aut  ...  \
# Layer                                                                   ...
# 11        ,   the   have     our  IS      s  based   to     G   enzyme  ...
# 10        ,   the      ,     the   ,      ,    and    ,   the      the  ...
# 9       the   the    the     the   ,      ,    and    ,   the        "  ...
# 8       the   the    the     the   -      ,    and    ,   and        "  ...
# 7       the   the    the     the   -      ,    and    ,   and        "  ...
# 6       the   the   have     the   -      ,    and    ,   and      new  ...
# 5       the   the    the     the   -      ,  based    ,   and      new  ...
# 4       the   the    the     the   -      ,  style   rd   and      new  ...
# 3       the   the    the     the   -      ,  style   rd   and      new  ...
# 2       the   the    the     the   G      ,     to   rd   the        "  ...
# 1         ,   the    the   train   G  ember     to   rd   the        "  ...
# 0         ,   the    the   train   G     PT    the    -   the      the  ...
#
#        gressive  language      model       ,    with   175  billion  \
# Layer
# 11     gressive         ,   learning       ,      to     a        ,
# 10            -         ,          ,       ,      to   the        ,
# 9             -         ,          ,       ,      to   the        -
# 8             -         ,          ,       ,     and   the        -
# 7         lease         ,          ,       ,     and   the        -
# 6         lease         ,          ,       ,   which   the        -
# 5         lease       and          ,       ,     and   the        -
# 4         lease         ,          ,       ,     the   the        -
# 3         lease         ,          ,       ,     the   the        -
# 2             -         ,          ,       ,     the   the        -
# 1           ore         -   language   model     the   the        -
# 0             -         ,          ,   model     the   the        -
#
#        parameters  ,  NEXT_TOKEN
# Layer
# 11          words  .         and
# 10              -  ,         and
# 9               -  ,         and
# 8               -  ,         and
# 7               -  ,   including
# 6               -  ,   including
# 5               -  ,         the
# 4               -  ,         the
# 3               -  ,         the
# 2               -  ,         the
# 1               -  ,         the
# 0              in  ,         the
#
# [12 rows x 21 columns]

# %%
from IPython.display import clear_output
def top1_ranks(hidden_states):
  top1_output_tokens = torch.argmax(desembed_state(hidden_states[-1][0]), dim=1)
  # token pour chaque prédiction
  # state : pour chaque prédiction pour chaque token, logit
  states = []
  for [state] in tqdm(hidden_states[::-1]):
    state = desembed_state(state)
    preds = []
    for i, pred in tqdm(enumerate(state)):
      sorted_l = sorted(pred, reverse=True)
      # print(len(sorted_l))
      logit_of_best = pred[top1_output_tokens[i]]
      preds.append(sorted_l.index(logit_of_best)+1)

      # print(sorted_l.index(logit_of_best))
    states.append(preds)
  df = pd.DataFrame(states).style.background_gradient(cmap='Blues')
  # df.columns = list(map(tokenizer.decode, torch.argmax(desembed_state(hidden_states[-1][0]), dim=1)))
  return df, list(map(tokenizer.decode, torch.argmax(desembed_state(hidden_states[-1][0]), dim=1)))

# %%
df_top, head = top1_ranks(hidden_states)
df_top
# Out:
#   0%|          | 0/13 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# <style type="text/css">
# #T_bb793_row0_col0, #T_bb793_row0_col1, #T_bb793_row0_col2, #T_bb793_row0_col3, #T_bb793_row0_col4, #T_bb793_row0_col5, #T_bb793_row0_col6, #T_bb793_row0_col7, #T_bb793_row0_col8, #T_bb793_row0_col9, #T_bb793_row0_col10, #T_bb793_row0_col11, #T_bb793_row0_col12, #T_bb793_row0_col13, #T_bb793_row0_col14, #T_bb793_row0_col15, #T_bb793_row0_col16, #T_bb793_row0_col17, #T_bb793_row0_col18, #T_bb793_row0_col19, #T_bb793_row0_col20, #T_bb793_row1_col0, #T_bb793_row1_col1, #T_bb793_row1_col3, #T_bb793_row1_col5, #T_bb793_row1_col7, #T_bb793_row1_col12, #T_bb793_row1_col14, #T_bb793_row1_col15, #T_bb793_row1_col17, #T_bb793_row1_col18, #T_bb793_row1_col19, #T_bb793_row1_col20, #T_bb793_row2_col0, #T_bb793_row2_col1, #T_bb793_row2_col3, #T_bb793_row2_col5, #T_bb793_row2_col7, #T_bb793_row2_col12, #T_bb793_row2_col14, #T_bb793_row2_col15, #T_bb793_row2_col17, #T_bb793_row2_col18, #T_bb793_row2_col19, #T_bb793_row2_col20, #T_bb793_row3_col0, #T_bb793_row3_col1, #T_bb793_row3_col3, #T_bb793_row3_col5, #T_bb793_row3_col6, #T_bb793_row3_col7, #T_bb793_row3_col11, #T_bb793_row3_col12, #T_bb793_row3_col14, #T_bb793_row3_col17, #T_bb793_row3_col18, #T_bb793_row3_col19, #T_bb793_row3_col
col3 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_bb793_row1_col11 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_bb793_row1_col16, #T_bb793_row2_col16, #T_bb793_row3_col8, #T_bb793_row3_col15, #T_bb793_row3_col16, #T_bb793_row4_col16, #T_bb793_row5_col16, #T_bb793_row6_col16, #T_bb793_row7_col16, #T_bb793_row8_col16, #T_bb793_row9_col16, #T_bb793_row10_col16, #T_bb793_row11_col2, #T_bb793_row11_col16 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_bb793_row2_col2, #T_bb793_row2_col6, #T_bb793_row2_col11, #T_bb793_row3_col2, #T_bb793_row4_col2, #T_bb793_row5_col11, #T_bb793_row6_col13, #T_bb793_row7_col2, #T_bb793_row8_col2, #T_bb793_row9_col2, #T_bb793_row10_col2, #T_bb793_row11_col18 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_bb793_row2_col4 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_bb793_row2_col8, #T_bb793_row3_col10, #T_bb793_row4_col10, #T_bb793_row11_col13 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_bb793_row2_col9, #T_bb793_row5_col10 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_bb793_row3_col4, #T_bb793_row7_col11 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_bb793_row3_col9, #T_bb793_row4_col8, #T_bb793_row8_col11 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_bb793_row4_col9, #T_bb793_row11_col4 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_bb793_row4_col15 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_bb793_row4_col20, #T_bb793_row6_col20, #T_bb793_row7_col20, #T_bb793_row8_col20, #T_bb793_row9_col20, #T_bb793_row10_col20 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_bb793_row5_col4 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_bb793_row5_col8, #T_bb793_row6_col4, #T_bb793_row10_col8, #T_bb793_row11_col10 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_bb793_row5_col9 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_bb793_row5_col15 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_bb793_row5_col20, #T_bb793_row11_col20 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_bb793_row6_col8 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_bb793_row6_col9 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_bb793_row6_col11 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_bb793_row6_col15 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_bb793_row7_col4, #T_bb793_row7_col8, #T_bb793_row10_col4 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_bb793_row7_col9 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_bb793_row7_col15 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_bb793_row8_col4 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_bb793_row8_col8, #T_bb793_row9_col8 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_bb793_row8_col9 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_bb793_row8_col15 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_bb793_row9_col4 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_bb793_row9_col9 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_bb793_row9_col10, #T_bb793_row11_col6 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_bb793_row9_col11 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_bb793_row9_col15 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_bb793_row10_col9 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_bb793_row10_col11 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_bb793_row10_col15, #T_bb793_row11_col9, #T_bb793_row11_col11, #T_bb793_row12_col0, #T_bb793_row12_col1, #T_bb793_row12_col2, #T_bb793_row12_col3, #T_bb793_row12_col4, #T_bb793_row12_col5, #T_bb793_row12_col6, #T_bb793_row12_col7, #T_bb793_row12_col8, #T_bb793_row12_col10, #T_bb793_row12_col12, #T_bb793_row12_col13, #T_bb793_row12_col14, #T_bb793_row12_col16, #T_bb793_row12_col17, #T_bb793_row12_col18, #T_bb793_row12_col19, #T_bb793_row12_col20 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_bb793_row11_col8 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_bb793_row11_col15 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_bb793_row12_col9 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_bb793_row12_col11 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_bb793_row12_col15 {
#   backgro
